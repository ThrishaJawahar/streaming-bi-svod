# %% [markdown]
# # 01 — Explore SVoD Dataset
#
# This notebook loads and explores the Streaming dataset (Netflix, Hulu, Prime Video, Disney+).

# %%
# !pip install pandas
# !pip install matplotlib
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

DATA_DIR = Path.cwd().parents[0] / "data"  # adjust if needed
# Example: 
df = pd.read_csv(DATA_DIR / "svod_sample.csv")
print("Place your dataset (e.g., svod_sample.csv) in the data/ folder.")
# Out:
# Requirement already satisfied: pandas in c:\users\dell\downloads\streaming-bi-template\streaming-bi-template\.venv\lib\site-packages (3.0.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\dell\downloads\streaming-bi-template\streaming-bi-template\.venv\lib\site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\downloads\streaming-bi-template\streaming-bi-template\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\dell\downloads\streaming-bi-template\streaming-bi-template\.venv\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\dell\downloads\streaming-bi-template\streaming-bi-template\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\users\dell\downloads\streaming-bi-template\streaming-bi-template\.venv\lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\downloads\streaming-bi-template\streaming-bi-template\.venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\downloads\streaming-bi-template\streaming-bi-template\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\downloads\streaming-bi-template\streaming-bi-template\.venv\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dell\downloads\streaming-bi-template\streaming-bi-template\.venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\dell\downloads\streaming-bi-template\streaming-bi-template\.venv\lib\site-packages (from matplotlib) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\downloads\streaming-bi-template\streaming-bi-template\.venv\lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\dell\downloads\streaming-bi-template\streaming-bi-template\.venv\lib\site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\dell\downloads\streaming-bi-template\streaming-bi-template\.venv\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\downloads\streaming-bi-template\streaming-bi-template\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\dell\downloads\streaming-bi-template\streaming-bi-template\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 9
#       7 DATA_DIR = Path.cwd().parents[0] / "data"  # adjust if needed
#       8 # Example:
# ----> 9 df = pd.read_csv(DATA_DIR / "svod_sample.csv")
#      10 print("Place your dataset (e.g., svod_sample.csv) in the data/ folder.")
#
# File ~\Downloads\streaming-bi-template\streaming-bi-template\.venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~\Downloads\streaming-bi-template\streaming-bi-template\.venv\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~\Downloads\streaming-bi-template\streaming-bi-template\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~\Downloads\streaming-bi-template\streaming-bi-template\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~\Downloads\streaming-bi-template\streaming-bi-template\.venv\Lib\site-packages\pandas\io\common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     921 elif isinstance(handle, str):
#     922     # Check whether the filename is to be opened in binary mode.
#     923     # Binary mode does not support 'encoding' and 'newline'.
#     924     if ioargs.encoding and "b" not in ioargs.mode:
#     925         # Encoding
# --> 926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#     929             encoding=ioargs.encoding,
#     930             errors=errors,
#     931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
#     935         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Dell\\Downloads\\streaming-bi-template\\streaming-bi-template\\data\\svod_sample.csv'

# %%
# Example EDA once data is loaded
# df.head()
# df.info()
# df.describe(numeric_only=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Example EDA once data is loaded
# ----> 2 df.head()
#       3 df.info()
#       4 df.describe(numeric_only=True)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Quick Plot Example

# %%
# if 'watch_time' in df.columns:
#     df['watch_time'].hist()
#     plt.title('Watch Time Distribution')
#     plt.show()
